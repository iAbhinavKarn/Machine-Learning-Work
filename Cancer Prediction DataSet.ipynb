# %% [markdown]
# # Cancer Prediction

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Cancer data set.txt')

# %%
df.head(25)
# Out:
#          id  clump_thickness  unif_cell_size  unif_cell_shape  marg_adhesion  \
# 0   1000025                5               1                1              1
# 1   1002945                5               4                4              5
# 2   1015425                3               1                1              1
# 3   1016277                6               8                8              1
# 4   1017023                4               1                1              3
# 5   1017122                8              10               10              8
# 6   1018099                1               1                1              1
# 7   1018561                2               1                2              1
# 8   1033078                2               1                1              1
# 9   1033078                4               2                1              1
# 10  1035283                1               1                1              1
# ...

# %%
df.isna().values.any()
# Out:
# False

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# id                        699 non-null int64
# clump_thickness           699 non-null int64
# unif_cell_size            699 non-null int64
# unif_cell_shape           699 non-null int64
# marg_adhesion             699 non-null int64
# single_epith_cell_size    699 non-null int64
# bare_nuclei               699 non-null object
# bland_chrom               699 non-null int64
# norm_nucleoli             699 non-null int64
# mitoses                   699 non-null int64
# class                     699 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 60.1+ KB

# %%
df.corr()
# Out:
#                               id  clump_thickness  unif_cell_size  \
# id                      1.000000        -0.055308       -0.041603
# clump_thickness        -0.055308         1.000000        0.644913
# unif_cell_size         -0.041603         0.644913        1.000000
# unif_cell_shape        -0.041576         0.654589        0.906882
# marg_adhesion          -0.064878         0.486356        0.705582
# single_epith_cell_size -0.045528         0.521816        0.751799
# bland_chrom            -0.060051         0.558428        0.755721
# norm_nucleoli          -0.052072         0.535835        0.722865
# mitoses                -0.034901         0.350034        0.458693
# class                  -0.080226         0.716001        0.817904
#
#                         unif_cell_shape  marg_adhesion  \
# id                            -0.041576      -0.064878
# clump_thickness                0.654589       0.486356
# unif_cell_size                 0.906882       0.705582
# ...

# %%
df = df.drop(['id'], axis = 1)

# %%
df
# Out:
#      clump_thickness  unif_cell_size  unif_cell_shape  marg_adhesion  \
# 0                  5               1                1              1
# 1                  5               4                4              5
# 2                  3               1                1              1
# 3                  6               8                8              1
# 4                  4               1                1              3
# 5                  8              10               10              8
# 6                  1               1                1              1
# 7                  2               1                2              1
# 8                  2               1                1              1
# 9                  4               2                1              1
# 10                 1               1                1              1
# 11                 2               1                1              1
# 12                 5               3                3              3
# ...

# %%
df.corr()
# Out:
#                         clump_thickness  unif_cell_size  unif_cell_shape  \
# clump_thickness                1.000000        0.644913         0.654589
# unif_cell_size                 0.644913        1.000000         0.906882
# unif_cell_shape                0.654589        0.906882         1.000000
# marg_adhesion                  0.486356        0.705582         0.683079
# single_epith_cell_size         0.521816        0.751799         0.719668
# bland_chrom                    0.558428        0.755721         0.735948
# norm_nucleoli                  0.535835        0.722865         0.719446
# mitoses                        0.350034        0.458693         0.438911
# class                          0.716001        0.817904         0.818934
#
#                         marg_adhesion  single_epith_cell_size  bland_chrom  \
# clump_thickness              0.486356                0.521816     0.558428
# unif_cell_size               0.705582                0.751799     0.755721
# ...

# %%
df = df.replace('?', np.nan)

# %%
df.isna().values.any()
# Out:
# True

# %%
df.bare_nuclei = pd.to_numeric(df.bare_nuclei)

# %%
df = df.fillna(method='ffill')

# %%
X = df.iloc[:,1:].values
y = df.iloc[:, 0].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state = 0)
model = LinearRegression(fit_intercept=True)
model.fit(Xtrain,ytrain)
y_model = model.predict(Xtest)
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('RsquareError = ',r2_score(ytest,y_model))
print('Mean Absolute Error = ',mean_absolute_error(ytest,y_model))
print('Root mean Square Error = ',np.sqrt(mean_squared_error(ytest,y_model)))
# Out:
# C:\Users\Abhinav\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# RsquareError =  0.5671331145162662
# Mean Absolute Error =  1.597296437043348
# Root mean Square Error =  1.9115419978913653

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
import seaborn as sns
model = GaussianNB()
x = df.iloc[:, :9].values
y = df.iloc[:, 9].values
model.fit(x, y)
y_pred = model.predict(x)
print(metrics.classification_report(y, y_pred))
print(metrics.confusion_matrix(y, y_pred))
mat = metrics.confusion_matrix(y, y_pred)

from sklearn.metrics import accuracy_score

print('\n Accuracy Score = ',accuracy_score(y, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           2       0.98      0.95      0.97       458
#           4       0.91      0.97      0.94       241
#
# avg / total       0.96      0.96      0.96       699
#
# [[435  23]
#  [  7 234]]
#
#  Accuracy Score =  0.9570815450643777

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB
import seaborn as sns
model = MultinomialNB()
x = df.iloc[:, :9].values
y = df.iloc[:, 9].values
model.fit(x, y)
y_pred = model.predict(x)
print(metrics.classification_report(y, y_pred))
print(metrics.confusion_matrix(y, y_pred))
mat = metrics.confusion_matrix(y, y_pred)

from sklearn.metrics import accuracy_score

print('\n Accuracy Score = ',accuracy_score(y, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           2       0.90      0.95      0.93       458
#           4       0.89      0.81      0.85       241
#
# avg / total       0.90      0.90      0.90       699
#
# [[434  24]
#  [ 46 195]]
#
#  Accuracy Score =  0.899856938483548

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.naive_bayes import BernoulliNB
import seaborn as sns
model = BernoulliNB()
x = df.iloc[:, :9].values
y = df.iloc[:, 9].values
model.fit(x, y)
y_pred = model.predict(x)
print(metrics.classification_report(y, y_pred))
print(metrics.confusion_matrix(y, y_pred))
mat = metrics.confusion_matrix(y, y_pred)

from sklearn.metrics import accuracy_score

print('\n Accuracy Score = ',accuracy_score(y, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           2       0.66      1.00      0.79       458
#           4       0.00      0.00      0.00       241
#
# avg / total       0.43      0.66      0.52       699
#
# [[458   0]
#  [241   0]]
#
#  Accuracy Score =  0.6552217453505007
# C:\Users\Abhinav\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import datasets

x = df.iloc[:, :9].values
y = df.iloc[:, 9].values

sc = StandardScaler()
x = sc.fit_transform(x)

xtrain,xtest,ytrain,ytest = train_test_split(x, y, test_size = 0.3, random_state = 0)
model = SVC(kernel = 'rbf', C = 1.0, random_state = 0, gamma = 'auto').fit(xtrain, ytrain)

print('Train Accuracy Score = ', metrics.accuracy_score(ytrain, model.predict(xtrain)))
print('\nTrain Confusion Metrics = ', metrics.confusion_matrix(ytrain, model.predict(xtrain)))
print('\nTest Accuracy Score = ', metrics.accuracy_score(ytest, model.predict(xtest)))
print('\nTest Confusion Metrics = ', metrics.confusion_matrix(ytest, model.predict(xtest)))
print('\nClassification Report = ', metrics.classification_report(ytest, model.predict(xtest)))
# Out:
# Train Accuracy Score =  0.9815950920245399
#
# Train Confusion Metrics =  [[317   6]
#  [  3 163]]
#
# Test Accuracy Score =  0.9476190476190476
#
# Test Confusion Metrics =  [[128   7]
#  [  4  71]]
#
# Classification Report =               precision    recall  f1-score   support
#
#           2       0.97      0.95      0.96       135
#           4       0.91      0.95      0.93        75
#
# avg / total       0.95      0.95      0.95       210
